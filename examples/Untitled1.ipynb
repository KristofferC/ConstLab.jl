# %%
using Colors
using Plots

# %%
distinguishable_colors(15)
# Out:
# 15-element Array{ColorTypes.RGB{FixedPointNumbers.UfixedBase{UInt8,8}},1}:
#  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(1.0,0.608,1.0)
#  RGB{U8}(0.0,1.0,1.0)
#  RGB{U8}(0.914,0.514,0.0)
#  RGB{U8}(0.0,0.522,1.0)
#  RGB{U8}(0.0,0.569,0.0)
#  RGB{U8}(0.914,0.0,0.412)
#  RGB{U8}(0.0,0.518,0.765)
#  RGB{U8}(0.976,1.0,0.055)
#  RGB{U8}(0.596,0.0,0.0)
#  RGB{U8}(0.953,0.988,1.0)
#  RGB{U8}(0.0,0.063,0.706)
#  RGB{U8}(0.306,0.188,0.0)
#  RGB{U8}(0.0,0.271,0.82)
#  RGB{U8}(0.718,0.576,0.584)

# %%
pyplot()
plot(cumsum(randn(10,15),1); w = 5)
# Out:
# [Plots.jl] Initializing backend: pyplot
# Plot{Plots.PyPlotPackage() n=15}

# %%
p = plot()
cols = distinguishable_colors(15)
for col in cols
    plot!(cumsum(randn(10),1); w = 5, color = col)
end
p
# Out:
# Plot{Plots.WinstonPackage() n=15}
